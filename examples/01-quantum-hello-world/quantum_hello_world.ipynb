# %% [markdown]
# <a href="https://colab.research.google.com/github/micahmg99/quantum-hello-world/blob/main/quantum-hello-world.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#micah gentry
#quantum hello world

from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram

# 2 qubits, 2 classical bits
qc = QuantumCircuit(2)

#add a hadamard gate to qubit 0
qc.h(0)

#perform a controlled x gate on qubit 1, controlled by qubit 0
qc.cx(0, 1)

#draw the circuit
print(qc.draw())
# Out:
#      ┌───┐
# q_0: ┤ H ├──■──
#      └───┘┌─┴─┐
# q_1: ─────┤ X ├
#           └───┘
